# %% [markdown]
# **复习：**在前面我们已经学习了Pandas基础，第二章我们开始进入数据分析的业务部分，在第二章第一节的内容中，我们学习了**数据的清洗**，这一部分十分重要，只有数据变得相对干净，我们之后对数据的分析才可以更有力。而这一节，我们要做的是数据重构，数据重构依旧属于数据理解（准备）的范围。

# %% [markdown]
# #### 开始之前，导入numpy、pandas包和数据

# %%
# 导入基本库
import numpy as np
import pandas as pd

# %%
# 载入data文件中的:train-left-up.csv
data_train = pd.read_csv('./data/train-left-up.csv')
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 434          435         0       1
# 435          436         1       1
# 436          437         0       3
# 437          438         1       2
# 438          439         0       1
#
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 434                          Silvey, Mr. William Baird
# 435                          Carter, Miss. Lucile Polk
# ...

# %% [markdown]
# # 2 第二章：数据重构

# %% [markdown]
# ### 2.4 数据的合并

# %% [markdown]
# #### 2.4.1 任务一：将data文件夹里面的所有数据都载入，观察数据的之间的关系

# %%
#写入代码
import os
for i in os.walk('./data/'):
    print(i)
# Out:
# ('./data/', [], ['.DS_Store', 'train-left-down.csv', 'train-left-up.csv', 'train-right-down.csv', 'train-right-up.csv'])

# %%
#写入代码
data_tld = pd.read_csv('./data/train-left-down.csv')
data_tld.head(2)
# Out:
#    PassengerId  Survived  Pclass                                         Name
# 0          440         0       2       Kvillner, Mr. Johan Henrik Johannesson
# 1          441         1       2  Hart, Mrs. Benjamin (Esther Ada Bloomfield)

# %%
data_tlu = pd.read_csv('./data/train-left-up.csv')
data_tlu.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
data_trd = pd.read_csv('./data/train-right-down.csv')
data_trd.head(2)
# Out:
#       Sex   Age  SibSp  Parch        Ticket   Fare Cabin Embarked
# 0    male  31.0      0      0    C.A. 18723  10.50   NaN        S
# 1  female  45.0      1      1  F.C.C. 13529  26.25   NaN        S

# %%
data_tru = pd.read_csv('./data/train-right-up.csv')
data_tru.head(2)
# Out:
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# 【提示】结合之前我们加载的train.csv数据，大致预测一下上面的数据是什么

# %% [markdown]
# #### 2.4.2：任务二：使用concat方法：将数据train-left-up.csv和train-right-up.csv横向合并为一张表，并保存这张表为result_up

# %%
#写入代码

result_up = pd.concat([data_tlu, data_tru], axis=1)
result_up.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### 2.4.3 任务三：使用concat方法：将train-left-down和train-right-down横向合并为一张表，并保存这张表为result_down。然后将上边的result_up和result_down纵向合并为result。

# %%
#写入代码

result_down = pd.concat([data_tld, data_trd], axis=1)
result_down.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          440         0       2       Kvillner, Mr. Johan Henrik Johannesson
# 1          441         1       2  Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# 2          442         0       3                              Hampe, Mr. Leon
# 3          443         0       3                    Petterson, Mr. Johan Emil
# 4          444         1       2                    Reynaldo, Ms. Encarnacion
#
#       Sex   Age  SibSp  Parch        Ticket    Fare Cabin Embarked
# 0    male  31.0      0      0    C.A. 18723  10.500   NaN        S
# 1  female  45.0      1      1  F.C.C. 13529  26.250   NaN        S
# 2    male  20.0      0      0        345769   9.500   NaN        S
# 3    male  25.0      1      0        347076   7.775   NaN        S
# 4  female  28.0      0      0        230434  13.000   NaN        S

# %%
result = pd.concat([result_up, result_down], axis=0)
result.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 447          887         0       2                     Montvila, Rev. Juozas
# 448          888         1       1              Graham, Miss. Margaret Edith
# 449          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 450          890         1       1                     Behr, Mr. Karl Howell
# 451          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 447    male  27.0      0      0      211536  13.00   NaN        S
# 448  female  19.0      0      0      112053  30.00   B42        S
# 449  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 450    male  26.0      0      0      111369  30.00  C148        C
# 451    male  32.0      0      0      370376   7.75   NaN        Q

# %%
result = result.reset_index(drop=True)
result.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### 2.4.4 任务四：使用DataFrame自带的方法join方法和append：完成任务二和任务三的任务

# %%
#写入代码

result_up1 = data_tlu.join(data_tru, how='left')
result_up1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
result_down1 = data_tld.join(data_trd, how='left')
result_down1.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          440         0       2       Kvillner, Mr. Johan Henrik Johannesson
# 1          441         1       2  Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# 2          442         0       3                              Hampe, Mr. Leon
# 3          443         0       3                    Petterson, Mr. Johan Emil
# 4          444         1       2                    Reynaldo, Ms. Encarnacion
#
#       Sex   Age  SibSp  Parch        Ticket    Fare Cabin Embarked
# 0    male  31.0      0      0    C.A. 18723  10.500   NaN        S
# 1  female  45.0      1      1  F.C.C. 13529  26.250   NaN        S
# 2    male  20.0      0      0        345769   9.500   NaN        S
# 3    male  25.0      1      0        347076   7.775   NaN        S
# 4  female  28.0      0      0        230434  13.000   NaN        S

# %%
result1 = result_up1.append(result_down1)
result1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 447          887         0       2                     Montvila, Rev. Juozas
# 448          888         1       1              Graham, Miss. Margaret Edith
# 449          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 450          890         1       1                     Behr, Mr. Karl Howell
# 451          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 447    male  27.0      0      0      211536  13.00   NaN        S
# 448  female  19.0      0      0      112053  30.00   B42        S
# 449  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 450    male  26.0      0      0      111369  30.00  C148        C
# 451    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### 2.4.5 任务五：使用Panads的merge方法和DataFrame的append方法：完成任务二和任务三的任务

# %%
#写入代码

result_up2 = pd.merge(data_tlu, data_tru, left_index=True, right_index=True)
result_up2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
result_down2 = pd.merge(data_tld, data_trd, left_index=True, right_index=True)
result_down2.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          440         0       2       Kvillner, Mr. Johan Henrik Johannesson
# 1          441         1       2  Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# 2          442         0       3                              Hampe, Mr. Leon
# 3          443         0       3                    Petterson, Mr. Johan Emil
# 4          444         1       2                    Reynaldo, Ms. Encarnacion
#
#       Sex   Age  SibSp  Parch        Ticket    Fare Cabin Embarked
# 0    male  31.0      0      0    C.A. 18723  10.500   NaN        S
# 1  female  45.0      1      1  F.C.C. 13529  26.250   NaN        S
# 2    male  20.0      0      0        345769   9.500   NaN        S
# 3    male  25.0      1      0        347076   7.775   NaN        S
# 4  female  28.0      0      0        230434  13.000   NaN        S

# %%
result2 = result_up2.append(result_down2)
result2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 447          887         0       2                     Montvila, Rev. Juozas
# 448          888         1       1              Graham, Miss. Margaret Edith
# 449          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 450          890         1       1                     Behr, Mr. Karl Howell
# 451          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 447    male  27.0      0      0      211536  13.00   NaN        S
# 448  female  19.0      0      0      112053  30.00   B42        S
# 449  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 450    male  26.0      0      0      111369  30.00  C148        C
# 451    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# 【思考】对比merge、join以及concat的方法的不同以及相同。思考一下在任务四和任务五的情况下，为什么都要求使用DataFrame的append方法，如何只要求使用merge或者join可不可以完成任务四和任务五呢？

# %% [markdown]
# join和merge比较适合于按指定列名合并，其它列名则会视为不同列而在新表中产生新的列，从而导致列的增加，产品的数据并不准确，目前是这样认为，或许能有解决的办法？？

# %%
temp = pd.merge(result_up2, result_down2, on='PassengerId', how='outer')
temp.tail()
# Out:
#      PassengerId  Survived_x  Pclass_x Name_x Sex_x  Age_x  SibSp_x  Parch_x  \
# 886          887         NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 887          888         NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 888          889         NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 889          890         NaN       NaN    NaN   NaN    NaN      NaN      NaN
# 890          891         NaN       NaN    NaN   NaN    NaN      NaN      NaN
#
#     Ticket_x  Fare_x  ... Pclass_y                                    Name_y  \
# 886      NaN     NaN  ...      2.0                     Montvila, Rev. Juozas
# 887      NaN     NaN  ...      1.0              Graham, Miss. Margaret Edith
# 888      NaN     NaN  ...      3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889      NaN     NaN  ...      1.0                     Behr, Mr. Karl Howell
# 890      NaN     NaN  ...      3.0                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# #### 2.4.6 任务六：完成的数据保存为result.csv

# %%
#写入代码

result.to_csv('./result.csv', index='False')

# %% [markdown]
# ### 2.5 换一种角度看数据

# %% [markdown]
# #### 2.5.1 任务一：将我们的数据变为Series类型的数据

# %%
#写入代码

temp = pd.read_csv('./result.csv')
temp.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#写入代码

pd.Series(temp.Name.values)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Length: 891, dtype: object

# %% [markdown]
# 看不明白，这个转换的意义是什么，起到什么样的作用？还是只为了练习？
